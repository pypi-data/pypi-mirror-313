# %%
# %pip install pandas
# %pip install lgfk --upgrade --index-url https://__token__:gldt-QjbnZe7q2riYCziqWHCV@gitlab.in2p3.fr/api/v4/projects/20034/packages/pypi/simple
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://__token__:****@gitlab.in2p3.fr/api/v4/projects/20034/packages/pypi/simple
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from lgfk.monitoring import service
from lgfk.monitoring.types import MonitoringStorage

# %%
import os

os.environ["S3_BUCKET"] = "cnesdccgcpextbba"
os.environ["AWS_ENDPOINT_URL"] = "https://storage.googleapis.com"
os.environ["AWS_ACCESS_KEY_ID"] = "..."
os.environ["AWS_SECRET_ACCESS_KEY"] = "..."  #  noqa: S105

# %%
async with MonitoringStorage.from_env() as storage:
    pipeline_executions = await service.get_runs(storage)

pd.DataFrame.from_dict(pipeline_executions["runs"])
# Out:
#                                      run_id                             date
# 0  b7f09502a501b4a6f000c59accc890c1e5b69a29 2024-07-04 13:36:58.587000+00:00

# %%
run_id = "b7f09502a501b4a6f000c59accc890c1e5b69a29"
async with MonitoringStorage.from_env() as storage:
    execution_groups = await service.get_run_groups(storage, run_id)

pd.DataFrame.from_dict(execution_groups["groups"])
# Out:
#   group_id     modules
# 0     stub  [160, 282]

# %%
group_id = "stub"
module_id = "282"
async with MonitoringStorage.from_env() as storage:
    module = await service.get_run_group_module(storage, run_id, group_id, module_id)

pd.DataFrame.from_dict(execution_groups["groups"])
# Out:
#   group_id     modules
# 0     stub  [160, 282]

# %%
from IPython.display import HTML, display

display(HTML(module["plots"][0]["src"]))
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" width="396pt" height="396pt" viewBox="0 0 396 396" xmlns="http://www.w3.org/2000/svg" version="1.1">
#  <metadata>
#   <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#    <cc:Work>
#     <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>
#     <dc:date>2024-07-11T17:26:31.660340</dc:date>
#     <dc:format>image/svg+xml</dc:format>
#     <dc:creator>
#      <cc:Agent>
#       <dc:title>Matplotlib v3.8.3, https://matplotlib.org/</dc:title>
#      </cc:Agent>
#     </dc:creator>
#    </cc:Work>
#   </rdf:RDF>
#  </metadata>
#  <defs>
#   <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>
#  </defs>
#  <g id="figure_1">
# ...
