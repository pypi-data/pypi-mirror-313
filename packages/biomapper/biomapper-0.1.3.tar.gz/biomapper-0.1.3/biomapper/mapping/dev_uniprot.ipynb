# %%
import requests
import time
from typing import List, Dict, Any, Optional
from dataclasses import dataclass

@dataclass
class UniProtConfig:
    """Configuration for UniProt API client"""
    base_url: str = "https://rest.uniprot.org"
    polling_interval: int = 3
    max_retries: int = 5

class UniProtMappingError(Exception):
    """Custom exception for UniProt mapping errors"""
    pass

class UniProtMapper:
    """Client for UniProt ID mapping service"""
    
    def __init__(self, config: Optional[UniProtConfig] = None):
        """Initialize the UniProt mapping client
        
        Args:
            config: Optional configuration object
        """
        self.config = config or UniProtConfig()
        self.session = self._create_session()
    
    def _create_session(self) -> requests.Session:
        """Create requests session with retries"""
        session = requests.Session()
        retries = requests.adapters.Retry(
            total=self.config.max_retries,
            backoff_factor=0.25,
            status_forcelist=[500, 502, 503, 504]
        )
        session.mount("https://", requests.adapters.HTTPAdapter(max_retries=retries))
        return session
    
    def _check_response(self, response: requests.Response) -> None:
        """Check response for errors"""
        try:
            response.raise_for_status()
        except requests.HTTPError:
            raise UniProtMappingError(f"Request failed: {response.text}")
    
    def submit_mapping_job(self, from_db: str, to_db: str, ids: List[str]) -> str:
        """Submit an ID mapping job
        
        Args:
            from_db: Source database (e.g., "UniProtKB_AC-ID")
            to_db: Target database (e.g., "Ensembl")
            ids: List of identifiers to map
            
        Returns:
            str: Job ID for checking results
        """
        request = self.session.post(
            f"{self.config.base_url}/idmapping/run",
            data={
                "from": from_db,
                "to": to_db,
                "ids": ",".join(ids)
            }
        )
        self._check_response(request)
        return request.json()["jobId"]
    
    def check_job_status(self, job_id: str) -> Dict[str, Any]:
        """Check if mapping job is complete
        
        Args:
            job_id: Job ID from submit_mapping_job
            
        Returns:
            Dict containing status information or results redirect
            
        Raises:
            UniProtMappingError: If job failed
        """
        request = self.session.get(
            f"{self.config.base_url}/idmapping/status/{job_id}",
            allow_redirects=False
        )
        
        # Handle 303 redirect which indicates results are ready
        if request.status_code == 303:
            redirect_url = request.headers.get("Location")
            if redirect_url:
                return {"redirect": redirect_url}
            
        self._check_response(request)
        return request.json()
    
    def get_mapping_results(self, results_url: str) -> Dict[str, Any]:
        """Get mapping results from URL
        
        Args:
            results_url: URL for retrieving results
            
        Returns:
            Dict containing mapping results with 'results' and 'failedIds' keys
        """
        request = self.session.get(results_url)
        self._check_response(request)
        return request.json()
    
    def map_ids(self, from_db: str, to_db: str, ids: List[str]) -> Dict[str, Any]:
        """Complete ID mapping workflow
        
        Args:
            from_db: Source database (e.g., "UniProtKB_AC-ID")
            to_db: Target database (e.g., "Ensembl")
            ids: List of identifiers to map
            
        Returns:
            Dict containing mapping results
        """
        # Submit job
        job_id = self.submit_mapping_job(from_db, to_db, ids)
        
        # Poll until complete
        while True:
            status = self.check_job_status(job_id)
            
            # If we get a redirect URL, results are ready
            if "redirect" in status:
                return self.get_mapping_results(status["redirect"])
                
            # If still running, wait and try again
            if "jobStatus" in status:
                if status["jobStatus"] in ("NEW", "RUNNING"):
                    time.sleep(self.config.polling_interval)
                    continue
                raise UniProtMappingError(f"Job failed: {status['jobStatus']}")
                
            # If we get results directly, return them
            if "results" in status or "failedIds" in status:
                return status
                
            raise UniProtMappingError("Unexpected response format")

# Example usage:
if __name__ == "__main__":
    # Initialize client
    mapper = UniProtMapper()
    
    # Example: Map UniProt accessions to Ensembl IDs
    try:
        results = mapper.map_ids(
            from_db="UniProtKB_AC-ID",
            to_db="Ensembl",
            ids=["P05067", "P12345"]
        )
        print("Successful mappings:")
        for mapping in results.get("results", []):
            print(f"From: {mapping['from']} -> To: {mapping['to']}")
        print("\nFailed IDs:")
        for failed_id in results.get("failedIds", []):
            print(failed_id)
    except UniProtMappingError as e:
        print(f"Mapping failed: {e}")
# Out:
# Successful mappings:
# From: P05067 -> To: ENSG00000142192.22
#
# Failed IDs:
# P12345

# %%
import requests
import time
import json
from typing import List, Dict, Any, Optional, Set
from dataclasses import dataclass
from concurrent.futures import ThreadPoolExecutor, as_completed

@dataclass
class UniProtConfig:
    """Configuration for UniProt API client"""
    base_url: str = "https://rest.uniprot.org"
    polling_interval: int = 3
    max_retries: int = 5
    max_workers: int = 3  # For parallel mapping requests

class UniProtMappingError(Exception):
    """Custom exception for UniProt mapping errors"""
    pass

class UniProtMapper:
    """Enhanced client for UniProt ID mapping service"""
    
    def __init__(self, config: Optional[UniProtConfig] = None):
        self.config = config or UniProtConfig()
        self.session = self._create_session()
        self._mapping_options = None
    
    def _create_session(self) -> requests.Session:
        """Create requests session with retries"""
        session = requests.Session()
        retries = requests.adapters.Retry(
            total=self.config.max_retries,
            backoff_factor=0.25,
            status_forcelist=[500, 502, 503, 504]
        )
        session.mount("https://", requests.adapters.HTTPAdapter(max_retries=retries))
        return session

    def _check_response(self, response: requests.Response) -> None:
        """Check response for errors"""
        try:
            response.raise_for_status()
        except requests.HTTPError:
            raise UniProtMappingError(f"Request failed: {response.text}")

    def get_mapping_options(self) -> Dict[str, Set[str]]:
        """Get available mapping options for each source database
        
        Returns:
            Dict mapping source databases to sets of possible target databases
        """
        if self._mapping_options is not None:
            return self._mapping_options

        # Get available fields from UniProt API
        response = self.session.get(f"{self.config.base_url}/configure/idmapping/fields")
        self._check_response(response)
        data = response.json()

        # Process rules and build mapping options
        options = {}
        rules = {rule["ruleId"]: rule for rule in data.get("rules", [])}
        
        for group in data.get("groups", []):
            for item in group.get("items", []):
                if item.get("from"):  # If this can be a source database
                    rule_id = item.get("ruleId")
                    if rule_id and rule_id in rules:
                        options[item["name"]] = set(rules[rule_id]["tos"])

        self._mapping_options = options
        return options

    def submit_mapping_job(self, from_db: str, to_db: str, ids: List[str]) -> str:
        """Submit an ID mapping job"""
        request = self.session.post(
            f"{self.config.base_url}/idmapping/run",
            data={
                "from": from_db,
                "to": to_db,
                "ids": ",".join(ids)
            }
        )
        self._check_response(request)
        return request.json()["jobId"]

    def check_job_status(self, job_id: str) -> Dict[str, Any]:
        """Check if mapping job is complete"""
        request = self.session.get(
            f"{self.config.base_url}/idmapping/status/{job_id}",
            allow_redirects=False
        )
        
        if request.status_code == 303:
            redirect_url = request.headers.get("Location")
            if redirect_url:
                return {"redirect": redirect_url}
            
        self._check_response(request)
        return request.json()

    def get_mapping_results(self, results_url: str) -> Dict[str, Any]:
        """Get mapping results from URL"""
        request = self.session.get(results_url)
        self._check_response(request)
        return request.json()

    def map_ids(self, from_db: str, to_db: str, ids: List[str]) -> Dict[str, Any]:
        """Map IDs between databases"""
        job_id = self.submit_mapping_job(from_db, to_db, ids)
        
        while True:
            status = self.check_job_status(job_id)
            
            if "redirect" in status:
                return self.get_mapping_results(status["redirect"])
                
            if "jobStatus" in status:
                if status["jobStatus"] in ("NEW", "RUNNING"):
                    time.sleep(self.config.polling_interval)
                    continue
                raise UniProtMappingError(f"Job failed: {status['jobStatus']}")
                
            if "results" in status or "failedIds" in status:
                return status
                
            raise UniProtMappingError("Unexpected response format")

    def map_to_all(self, from_db: str, ids: List[str]) -> Dict[str, Dict[str, Any]]:
        """Map IDs to all possible target databases
        
        Args:
            from_db: Source database
            ids: List of identifiers to map
            
        Returns:
            Dict mapping target databases to their respective mapping results
        """
        options = self.get_mapping_options()
        if from_db not in options:
            raise UniProtMappingError(f"Invalid source database: {from_db}")

        results = {}
        
        # Use ThreadPoolExecutor for parallel mapping requests
        with ThreadPoolExecutor(max_workers=self.config.max_workers) as executor:
            future_to_db = {
                executor.submit(self.map_ids, from_db, to_db, ids): to_db
                for to_db in options[from_db]
            }
            
            for future in as_completed(future_to_db):
                to_db = future_to_db[future]
                try:
                    results[to_db] = future.result()
                except Exception as e:
                    print(f"Warning: Mapping to {to_db} failed: {str(e)}")
                    continue
                    
        return results

    def print_mapping_summary(self, mapping_results: Dict[str, Dict[str, Any]], indent: int = 2) -> None:
        """Print a readable summary of mapping results
        
        Args:
            mapping_results: Results from map_to_all
            indent: Number of spaces to indent output
        """
        indent_str = " " * indent
        
        for to_db, result in mapping_results.items():
            print(f"\n{indent_str}=== Mappings to {to_db} ===")
            
            if "results" in result:
                print(f"{indent_str}Successful mappings:")
                for mapping in result["results"]:
                    from_id = mapping.get("from", "N/A")
                    to_id = mapping.get("to", "N/A")
                    if isinstance(to_id, dict):
                        to_id = to_id.get("id", "N/A")
                    print(f"{indent_str * 2}{from_id} -> {to_id}")
            
            if "failedIds" in result and result["failedIds"]:
                print(f"{indent_str}Failed IDs:")
                for failed_id in result["failedIds"]:
                    print(f"{indent_str * 2}{failed_id}")

# Example usage:
if __name__ == "__main__":
    # Initialize client
    mapper = UniProtMapper()
    
    try:
        # Get all available mappings for UniProt accessions
        print("\nAvailable mapping options:")
        options = mapper.get_mapping_options()
        for from_db, to_dbs in options.items():
            print(f"\n{from_db} can be mapped to:")
            for to_db in sorted(to_dbs):
                print(f"  - {to_db}")

        # Example: Map a UniProt ID to all possible target databases
        print("\nMapping example protein to all databases:")
        results = mapper.map_to_all(
            from_db="UniProtKB_AC-ID",
            ids=["P05067"]  # APP protein
        )
        
        # Print results summary
        mapper.print_mapping_summary(results)
        
    except UniProtMappingError as e:
        print(f"Mapping failed: {e}")
# Out:
# Available mapping options:
#
# UniProtKB_AC-ID can be mapped to:
#   - Allergome
#   - ArachnoServer
#   - Araport
#   - BioCyc
#   - BioGRID
#   - BioMuta
#   - CCDS
#   - CGD
#   - CPTAC
#   - CRC64
#   - ChEMBL
#   - ChiTaRS
#   - CollecTF
#   - ComplexPortal
#   - ConoServer
#   - DIP
#   - DMDM
#   - DNASU
#   - DisProt
#   - DrugBank
#   - EMBL-GenBank-DDBJ
#   - EMBL-GenBank-DDBJ_CDS
#   - ESTHER
#   - EchoBASE
#   - Ensembl
#   - Ensembl_Genomes
#   - Ensembl_Genomes_Protein
#   - Ensembl_Genomes_Transcript
#   - Ensembl_Protein
#   - Ensembl_Transcript
#   - FlyBase
#   - GI_number
#   - GeneCards
#   - GeneID
#   - GeneReviews
#   - GeneTree
#   - GeneWiki
#   - Gene_Name
#   - GenomeRNAi
#   - GlyConnect
#   - GuidetoPHARMACOLOGY
#   - HGNC
#   - HOGENOM
#   - IDEAL
#   - KEGG
#   - LegioList
#   - Leproma
#   - MEROPS
#   - MGI
#   - MIM
#   - MaizeGDB
#   - OMA
#   - OpenTargets
#   - Orphanet
#   - OrthoDB
#   - PATRIC
#   - PDB
#   - PHI-base
#   - PIR
#   - PeroxiBase
#   - PharmGKB
#   - PlantReactome
#   - PomBase
#   - ProteomicsDB
#   - PseudoCAP
#   - REBASE
#   - RGD
#   - Reactome
#   - RefSeq_Nucleotide
#   - RefSeq_Protein
#   - SGD
#   - STRING
#   - SwissLipids
#   - TCDB
#   - TreeFam
#   - TubercuList
#   - UCSC
#   - UniParc
#   - UniPathway
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#   - UniRef100
#   - UniRef50
#   - UniRef90
#   - VEuPathDB
#   - VGNC
#   - WBParaSite
#   - WBParaSite_Transcript-Protein
#   - WormBase
#   - WormBase_Protein
#   - WormBase_Transcript
#   - Xenbase
#   - ZFIN
#   - dictyBase
#   - eggNOG
#   - euHCVdb
#   - neXtProt
#
# UniParc can be mapped to:
#   - UniParc
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# UniRef50 can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#   - UniRef50
#
# UniRef90 can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#   - UniRef90
#
# UniRef100 can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#   - UniRef100
#
# Gene_Name can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# CRC64 can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# CCDS can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# EMBL-GenBank-DDBJ can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# EMBL-GenBank-DDBJ_CDS can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# GI_number can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# PIR can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# RefSeq_Nucleotide can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# RefSeq_Protein can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# PDB can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# BioGRID can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# ComplexPortal can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# DIP can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# STRING can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# ChEMBL can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# DrugBank can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# GuidetoPHARMACOLOGY can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# SwissLipids can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# Allergome can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# ESTHER can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# MEROPS can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# PeroxiBase can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# REBASE can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# TCDB can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# GlyConnect can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# BioMuta can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# DMDM can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# CPTAC can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# ProteomicsDB can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# DNASU can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# Ensembl can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# Ensembl_Genomes can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# Ensembl_Genomes_Protein can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# Ensembl_Genomes_Transcript can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# Ensembl_Protein can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# Ensembl_Transcript can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# GeneID can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# KEGG can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# PATRIC can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# UCSC can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# WBParaSite can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# WBParaSite_Transcript-Protein can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# ArachnoServer can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# Araport can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# CGD can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# ConoServer can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# dictyBase can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# EchoBASE can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# euHCVdb can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# FlyBase can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# GeneCards can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# GeneReviews can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# HGNC can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# LegioList can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# Leproma can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# MaizeGDB can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# MGI can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# MIM can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# neXtProt can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# OpenTargets can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# Orphanet can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# PharmGKB can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# PomBase can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# PseudoCAP can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# RGD can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# SGD can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# TubercuList can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# VEuPathDB can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# VGNC can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# WormBase can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# WormBase_Protein can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# WormBase_Transcript can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# Xenbase can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# ZFIN can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# eggNOG can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# GeneTree can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# HOGENOM can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# OMA can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# OrthoDB can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# TreeFam can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# BioCyc can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# PlantReactome can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# Reactome can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# UniPathway can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# ChiTaRS can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# GeneWiki can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# GenomeRNAi can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# PHI-base can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# CollecTF can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# DisProt can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# IDEAL can be mapped to:
#   - UniProtKB
#   - UniProtKB-Swiss-Prot
#
# Mapping example protein to all databases:
#
#   === Mappings to RefSeq_Protein ===
#   Successful mappings:
#     P05067 -> NP_000475.1
#     P05067 -> NP_001129488.1
#     P05067 -> NP_001129601.1
#     P05067 -> NP_001129602.1
#     P05067 -> NP_001129603.1
#     P05067 -> NP_001191230.1
#     P05067 -> NP_001191231.1
#     P05067 -> NP_001191232.1
#     P05067 -> NP_958816.1
#     P05067 -> NP_958817.1
#
#   === Mappings to TreeFam ===
#   Successful mappings:
#     P05067 -> TF317274
#
#   === Mappings to DIP ===
#   Successful mappings:
#     P05067 -> DIP-574N
#
#   === Mappings to STRING ===
#   Successful mappings:
#     P05067 -> 9606.ENSP00000284981
#
#   === Mappings to GeneID ===
#   Successful mappings:
#     P05067 -> 351
#
#   === Mappings to Reactome ===
#   Successful mappings:
#     P05067 -> R-HSA-114608
#     P05067 -> R-HSA-3000178
#     P05067 -> R-HSA-381426
#     P05067 -> R-HSA-416476
#     P05067 -> R-HSA-418594
#     P05067 -> R-HSA-432720
#     P05067 -> R-HSA-444473
#     P05067 -> R-HSA-445989
#     P05067 -> R-HSA-844456
#     P05067 -> R-HSA-879415
#     P05067 -> R-HSA-8862803
#     P05067 -> R-HSA-8957275
#     P05067 -> R-HSA-933542
#     P05067 -> R-HSA-9609523
#     P05067 -> R-HSA-9660826
#     P05067 -> R-HSA-977225
#     P05067 -> R-HSA-9837999
#
#   === Mappings to GenomeRNAi ===
#   Successful mappings:
#     P05067 -> 351
#
#   === Mappings to PeroxiBase ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to WBParaSite_Transcript-Protein ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to EMBL-GenBank-DDBJ ===
#   Successful mappings:
#     P05067 -> Y00264
#     P05067 -> X13466
#     P05067 -> X13467
#     P05067 -> X13468
#     P05067 -> X13469
#     P05067 -> X13470
#     P05067 -> X13471
#     P05067 -> X13472
#     P05067 -> X13473
#     P05067 -> X13474
#     P05067 -> X13475
#     P05067 -> X13476
#     P05067 -> X13477
#     P05067 -> X13478
#     P05067 -> X13479
#     P05067 -> X13487
#     P05067 -> X13488
#     P05067 -> X06989
#     P05067 -> M33112
#     P05067 -> M34862
#     P05067 -> M34863
#     P05067 -> M34864
#     P05067 -> M34865
#     P05067 -> M34866
#     P05067 -> M34867
#
#   === Mappings to UniRef50 ===
#   Successful mappings:
#     P05067 -> UniRef50_P05067
#
#   === Mappings to DisProt ===
#   Successful mappings:
#     P05067 -> DP01280
#
#   === Mappings to UniPathway ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to MGI ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to TubercuList ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to CGD ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to UniRef100 ===
#   Successful mappings:
#     P05067 -> UniRef100_P05067
#
#   === Mappings to Ensembl_Genomes_Protein ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to WormBase ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to WormBase_Protein ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to Leproma ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to DMDM ===
#   Successful mappings:
#     P05067 -> 112927
#
#   === Mappings to ComplexPortal ===
#   Successful mappings:
#     P05067 -> CPX-1062
#     P05067 -> CPX-1069
#     P05067 -> CPX-1070
#     P05067 -> CPX-1120
#     P05067 -> CPX-1134
#     P05067 -> CPX-1180
#
#   === Mappings to ChiTaRS ===
#   Successful mappings:
#     P05067 -> APP
#
#   === Mappings to PDB ===
#   Successful mappings:
#     P05067 -> 1AAP
#     P05067 -> 1AMB
#     P05067 -> 1AMC
#     P05067 -> 1AML
#     P05067 -> 1BA4
#     P05067 -> 1BA6
#     P05067 -> 1BJB
#     P05067 -> 1BJC
#     P05067 -> 1BRC
#     P05067 -> 1CA0
#     P05067 -> 1HZ3
#     P05067 -> 1IYT
#     P05067 -> 1MWP
#     P05067 -> 1OWT
#     P05067 -> 1QCM
#     P05067 -> 1QWP
#     P05067 -> 1QXC
#     P05067 -> 1QYT
#     P05067 -> 1TAW
#     P05067 -> 1TKN
#     P05067 -> 1X11
#     P05067 -> 1Z0Q
#     P05067 -> 1ZE7
#     P05067 -> 1ZE9
#     P05067 -> 1ZJD
#
#   === Mappings to ChEMBL ===
#   Successful mappings:
#     P05067 -> CHEMBL2487
#
#   === Mappings to RefSeq_Nucleotide ===
#   Successful mappings:
#     P05067 -> NM_000484.3
#     P05067 -> NM_001136016.3
#     P05067 -> NM_001136129.2
#     P05067 -> NM_001136130.2
#     P05067 -> NM_001136131.2
#     P05067 -> NM_001204301.1
#     P05067 -> NM_001204302.1
#     P05067 -> NM_001204303.1
#     P05067 -> NM_201413.2
#     P05067 -> NM_201414.2
#
#   === Mappings to UniParc ===
#   Successful mappings:
#     P05067 -> N/A
#
#   === Mappings to SwissLipids ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to TCDB ===
#   Successful mappings:
#     P05067 -> 1.C.50.1.2
#
#   === Mappings to GeneCards ===
#   Successful mappings:
#     P05067 -> APP
#
#   === Mappings to BioCyc ===
#   Successful mappings:
#     P05067 -> MetaCyc:ENSG00000142192-MONOMER
#
#   === Mappings to RGD ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to PIR ===
#   Successful mappings:
#     P05067 -> S01442
#     P05067 -> S02260
#
#   === Mappings to PseudoCAP ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to MaizeGDB ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to CRC64 ===
#   Successful mappings:
#     P05067 -> A12EE761403740F5
#
#   === Mappings to GlyConnect ===
#   Successful mappings:
#     P05067 -> 49
#
#   === Mappings to CollecTF ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to dictyBase ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to BioGRID ===
#   Successful mappings:
#     P05067 -> 106848
#
#   === Mappings to GeneTree ===
#   Successful mappings:
#     P05067 -> ENSGT00530000063252
#
#   === Mappings to UCSC ===
#   Successful mappings:
#     P05067 -> uc002ylz.4
#
#   === Mappings to WBParaSite ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to SGD ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to Allergome ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to PlantReactome ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to UniProtKB ===
#   Successful mappings:
#     P05067 -> N/A
#
#   === Mappings to MEROPS ===
#   Successful mappings:
#     P05067 -> I02.015
#
#   === Mappings to HOGENOM ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to WormBase_Transcript ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to Gene_Name ===
#   Successful mappings:
#     P05067 -> APP
#
#   === Mappings to Ensembl_Transcript ===
#   Successful mappings:
#     P05067 -> ENST00000346798.8
#     P05067 -> ENST00000348990.9
#     P05067 -> ENST00000354192.7
#     P05067 -> ENST00000357903.7
#     P05067 -> ENST00000358918.7
#     P05067 -> ENST00000440126.7
#
#   === Mappings to KEGG ===
#   Successful mappings:
#     P05067 -> hsa:351
#
#   === Mappings to ConoServer ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to Ensembl_Genomes ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to UniRef90 ===
#   Successful mappings:
#     P05067 -> UniRef90_P05067
#
#   === Mappings to FlyBase ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to CCDS ===
#   Successful mappings:
#     P05067 -> CCDS13576.1
#     P05067 -> CCDS13577.1
#     P05067 -> CCDS33523.1
#     P05067 -> CCDS46638.1
#     P05067 -> CCDS56212.1
#     P05067 -> CCDS56213.1
#
#   === Mappings to PharmGKB ===
#   Successful mappings:
#     P05067 -> PA24910
#
#   === Mappings to GuidetoPHARMACOLOGY ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to EMBL-GenBank-DDBJ_CDS ===
#   Successful mappings:
#     P05067 -> CAA68374.1
#     P05067 -> CAA31830.1
#     P05067 -> CAA30050.1
#     P05067 -> AAB59502.1
#     P05067 -> AAB59501.1
#     P05067 -> BAA22264.1
#     P05067 -> BAG35248.1
#     P05067 -> BAG58500.1
#     P05067 -> AAW82435.1
#     P05067 -> EAX09958.1
#     P05067 -> EAX09959.1
#     P05067 -> EAX09960.1
#     P05067 -> EAX09961.1
#     P05067 -> EAX09963.1
#     P05067 -> EAX09965.1
#     P05067 -> AAH04369.1
#     P05067 -> AAH65529.1
#     P05067 -> AAA60163.1
#     P05067 -> AAC13654.1
#     P05067 -> AAA58727.1
#     P05067 -> CAA30042.1
#     P05067 -> CAA30041.1
#     P05067 -> AAA51726.1
#     P05067 -> AAA51768.1
#     P05067 -> BAB71958.2
#
#   === Mappings to GeneReviews ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to IDEAL ===
#   Successful mappings:
#     P05067 -> IID00294
#
#   === Mappings to PHI-base ===
#   Successful mappings:
#
#   === Mappings to MIM ===
#   Successful mappings:
#     P05067 -> 104300
#     P05067 -> 104760
#     P05067 -> 605714
#
#   === Mappings to REBASE ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to eggNOG ===
#   Successful mappings:
#     P05067 -> KOG3540
#
#   === Mappings to DrugBank ===
#   Successful mappings:
#     P05067 -> DB12274
#     P05067 -> DB01370
#     P05067 -> DB14517
#     P05067 -> DB14518
#     P05067 -> DB05150
#     P05067 -> DB09130
#     P05067 -> DB00746
#     P05067 -> DB06782
#     P05067 -> DB05938
#     P05067 -> DB09148
#     P05067 -> DB09149
#     P05067 -> DB09151
#     P05067 -> DB12034
#     P05067 -> DB02235
#     P05067 -> DB14580
#     P05067 -> DB05846
#     P05067 -> DB04892
#     P05067 -> DB02709
#     P05067 -> DB05088
#     P05067 -> DB03754
#     P05067 -> DB01593
#     P05067 -> DB14487
#     P05067 -> DB14533
#     P05067 -> DB14548
#
#   === Mappings to ESTHER ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to OrthoDB ===
#   Successful mappings:
#     P05067 -> 2907766at2759
#
#   === Mappings to ArachnoServer ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to CPTAC ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to Ensembl_Genomes_Transcript ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to neXtProt ===
#   Successful mappings:
#     P05067 -> NX_P05067
#
#   === Mappings to VGNC ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to Xenbase ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to HGNC ===
#   Successful mappings:
#     P05067 -> HGNC:620
#
#   === Mappings to PomBase ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to Araport ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to GI_number ===
#   Successful mappings:
#     P05067 -> 1048348666
#     P05067 -> 355332874
#     P05067 -> 672885800
#     P05067 -> 810515317
#     P05067 -> 365812869
#     P05067 -> 374977470
#     P05067 -> 126030387
#     P05067 -> 194380694
#     P05067 -> 817598547
#     P05067 -> 408489409
#     P05067 -> 1009084372
#     P05067 -> 350610491
#     P05067 -> 817598544
#     P05067 -> 810515312
#     P05067 -> 178865
#     P05067 -> 307568212
#     P05067 -> 159162104
#     P05067 -> 973744144
#     P05067 -> 203282501
#     P05067 -> 178707
#     P05067 -> 119630368
#     P05067 -> 929612
#     P05067 -> 541881315
#     P05067 -> 365812826
#     P05067 -> 355332869
#
#   === Mappings to PATRIC ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to Ensembl ===
#   Successful mappings:
#     P05067 -> ENSG00000142192.22
#
#   === Mappings to UniProtKB-Swiss-Prot ===
#   Successful mappings:
#     P05067 -> N/A
#
#   === Mappings to LegioList ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to BioMuta ===
#   Successful mappings:
#     P05067 -> APP
#
#   === Mappings to ZFIN ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to euHCVdb ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to Orphanet ===
#   Successful mappings:
#     P05067 -> 324723
#     P05067 -> 100006
#     P05067 -> 324708
#     P05067 -> 324713
#     P05067 -> 324718
#     P05067 -> 324703
#     P05067 -> 1020
#
#   === Mappings to VEuPathDB ===
#   Successful mappings:
#     P05067 -> HostDB:ENSG00000142192
#
#   === Mappings to OMA ===
#   Successful mappings:
#     P05067 -> RERMSQX
#
#   === Mappings to DNASU ===
#   Successful mappings:
#     P05067 -> 351
#
#   === Mappings to Ensembl_Protein ===
#   Successful mappings:
#     P05067 -> ENSP00000284981.4
#     P05067 -> ENSP00000345463.5
#     P05067 -> ENSP00000346129.3
#     P05067 -> ENSP00000350578.3
#     P05067 -> ENSP00000351796.3
#     P05067 -> ENSP00000387483.2
#
#   === Mappings to ProteomicsDB ===
#   Successful mappings:
#     P05067 -> 4307
#     P05067 -> 51774
#     P05067 -> 51775
#     P05067 -> 51776
#     P05067 -> 51777
#     P05067 -> 51778
#     P05067 -> 51779
#     P05067 -> 51780
#     P05067 -> 51781
#     P05067 -> 51782
#     P05067 -> 51783
#
#   === Mappings to OpenTargets ===
#   Successful mappings:
#     P05067 -> ENSG00000142192
#
#   === Mappings to EchoBASE ===
#   Successful mappings:
#   Failed IDs:
#     P05067
#
#   === Mappings to GeneWiki ===
#   Successful mappings:
#     P05067 -> Amyloid_precursor_protein
